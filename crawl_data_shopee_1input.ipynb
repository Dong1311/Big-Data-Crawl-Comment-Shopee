# %%
# from google.colab import drive
# drive.mount('/content/drive')
import requests
import pandas as pd
import time
import random
from tqdm import tqdm
import os

# %%
# %cd /content/drive/MyDrive/DBM/crawl_data/Shopee
import os

os.chdir('./')

# %%
# !ls
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# from google.colab import files
# files.upload()
import pandas as pd

# Đọc file CSV từ thư mục hiện tại
df_id = pd.read_csv('./shopee_product_id.csv')  # ./ chỉ thư mục hiện tại

# Kiểm tra dữ liệu đã đọc được
print(df_id.head())
# Out:
# Empty DataFrame
# Columns: [https://shopee.vn/%C3%81o-thun-nam-c%E1%BB%95-tr%C3%B2n-HAFOS-%C3%81o-ph%C3%B4ng-nam-basic-tay-ng%E1%BA%AFn-ch%E1%BA%A5t-v%E1%BA%A3i-cotton-cao-c%E1%BA%A5p-th%E1%BA%A5m-h%C3%BAt-%C3%A1o-thun-tr%C6%A1n-basic-i.19687597.24157440408?sp_atk=d13bd307-d450-46cd-9449-71f3984a7b80&xptdk=d13bd307-d450-46cd-9449-71f3984a7b80]
# Index: []

# %%
import requests
import pandas as pd
import time
import random
from tqdm import tqdm

cookies = {
    'SPC_F':'6g4tsyNnAOVZrdkEothirX2vqOAKYKvG',
    'REC_T_ID':'1b90a284-60d7-11ee-9fac-347379167e6a',
    '_fbp':'fb.1.1696218749922.845714687',
    '_hjSessionUser_868286':'eyJpZCI6IjM4MDc4Mzk3LTkyYjktNWI5OC04ZTU5LTA5MTkwNDIzMjA2OCIsImNyZWF0ZWQiOjE2OTYyMTg3NTE3ODQsImV4aXN0aW5nIjp0cnVlfQ==',
    'SPC_CLIENTID':'Nmc0dHN5Tm5BT1Zakkvipnlfiezqpjbc',
    '_fbc':'fb.1.1696492052115.IwAR3s_t5R4-Eo_PkMsWA23tmIQDeOW5bBwvuO_HOdubaAe8_SnfMHKpCGk5I',
    'SPC_U':'-',
    'SPC_EC':'-',
    'SPC_R_T_ID':'aMpQVEaogeEgzC2REyIqgNf7HtAfXTZnpg/Na8ETLYtdN+zfyJVZmwkscsgLiaLubPk4wOZz2hiD/7WnGGPITLiSYjJQa7mrT1bjyaiL7dug9IU8hMEZeGmzlji2TQAnAABmEplJXni1v0TTuEElpSAcsxbTVdqiPg0HRgG1tzg=',
    'SPC_R_T_IV':'cDhScmF4ZHdmUTJEV3Nreg==',
    'SPC_T_ID':'aMpQVEaogeEgzC2REyIqgNf7HtAfXTZnpg/Na8ETLYtdN+zfyJVZmwkscsgLiaLubPk4wOZz2hiD/7WnGGPITLiSYjJQa7mrT1bjyaiL7dug9IU8hMEZeGmzlji2TQAnAABmEplJXni1v0TTuEElpSAcsxbTVdqiPg0HRgG1tzg=',
    'SPC_T_IV':'cDhScmF4ZHdmUTJEV3Nreg==',
    '_ga_M32T05RVZT':'GS1.1.1702584482.8.0.1702584482.60.0.0',
    '_gcl_au':'1.1.132621638.1704285163',
    'SPC_SEC_SI':'v1-Q0doV2lrOFBvRXR0c0tWUzqSIPnPlp6/s6X1lEQ6DmKult9Xnpyqiml+aAZ4WFrGQffJjLIlh/Q4Pfhzck2AF+XKvuVVoMsC17uQmkH/ukE=',
    'SPC_SI':'QQKdZQAAAAA4U21UOWc2cUgzIwAAAAAAUVg4ZjE0Y28=',
    '__LOCALE__null':'VN',
    'csrftoken':'HjkIff4F9AQvoVi8PQtF5REcH6U2DCWX',
    '_sapid':'4ca77247a7f4e72281a35b07b63eded22d2b34d5ddb91a83eab792c7',
    '_ga_4GPP1ZXG63':'GS1.1.1704943368.5.0.1704943368.0.0.0',
    '_QPWSDCXHZQA':'785dab59-3459-49bd-e656-dff710e22f59',
    'REC7iLP4Q':'81046d04-828d-428f-b5bf-41fd10567732',
    'shopee_webUnique_ccd':'8qu2xejEBqwAS28CkMddQA%3D%3D%7C6jucaHmWIlDbdL77vaMDskUuw4sN2oC6efijlAdrZZISf3l0wmtt5zPIFmFbyEIKP%2BfCr%2BojiZWQPQ%3D%3D%7CEbX67z8zoaWMskfm%7C08%7C3',
    'ds':'11970091b5c5d10f73297635039af2e2',
    'AMP_TOKEN':'%24NOT_FOUND',
    '_ga':'GA1.2.1754520024.1696218751',
    '_gid':'GA1.2.1338439444.1704943371',
    '_dc_gtm_UA-61914164-50':'1'

}

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36 Edg/120.0.0.0',
    'Accept': 'application/json',
    'Accept-Language': 'vi-VN,vi;q=0.8,en-US;q=0.5,en;q=0.3',
    'Accept-Encoding': 'gzip, deflate, br',
    'Referer': 'https://shopee.vn/G%C4%83ng-Tay-%C4%91i-ph%C6%B0%E1%BB%A3t-511-Ng%C3%B3n-C%E1%BB%A5t-(Lo%E1%BA%A1i-X%E1%BB%8Bn)-T%E1%BA%ADp-Gym-L%C3%A1i-xe-%C4%90i-ph%C6%B0%E1%BB%A3t-i.163364638.9746994645?sp_atk=2fd4383f-0ce1-4acd-9f96-0c57fad2eb3c&xptdk=2fd4383f-0ce1-4acd-9f96-0c57fad2eb3c',
    'X-Csrftoken': 'HjkIff4F9AQvoVi8PQtF5REcH6U2DCWX',
    'Connection': 'keep-alive',
    'TE': 'Trailers',
}

params = {
    'exclude_filter': '1',
    'filter': '0',
   ' filter_size': '0',
    'flag': '1',
    'fold_filter': '0',
    'itemid': '9746994645',
    'limit': '50',
    'offset': '0',
    'relevant_reviews': 'false',
    'request_source': '2',
    'shopid': '163364638',
    'tag_filter': '',
    'type': '0',
    'variation_filters': ''

}

def comment_parser(file_json, star):
    d = dict()
    d['itemid'] = file_json.get('ratings')[star].get('itemid')
    d['name'] = file_json.get('ratings')[star].get('product_items')[0].get('name')
    d['shopid']  = file_json.get('ratings')[star].get('shopid')
    d['userid'] = file_json.get('ratings')[star].get('userid')
    d['rating_star'] = file_json.get('ratings')[star].get('rating_star')
    d['comment'] = file_json.get('ratings')[star].get('comment')

    return d

# %%
import requests
import pandas as pd
import time
from tqdm import tqdm
import re

# Cấu hình API và cài đặt
BASE_URL = 'https://shopee.vn/api/v2/item/get_ratings'
params = {
    'exclude_filter': '1',
    'filter': '0',
    'filter_size': '0',
    'flag': '1',
    'fold_filter': '0',
    'limit': '50',  # Giới hạn số lượng đánh giá trả về mỗi lần gọi
    'offset': '0', # Offset cho trang hiện tại
    'relevant_reviews': 'false',
    'request_source': '2',
    'tag_filter': '',
    'type': '0',
    'variation_filters': ''
}

# Hàm lấy dữ liệu đánh giá
def make_request(item_id, shop_id, offset=0):
    # print(item_id)
    # print(shop_id)
    params['itemid'] = item_id
    params['shopid'] = shop_id
    params['offset'] = offset
    response = requests.get(BASE_URL, headers=headers, params=params, cookies=cookies)
    print(response.status_code)
    response.raise_for_status()
    return response

def extract_ids_from_url(url):
    match = re.search(r'i\.(\d+)\.(\d+)', url)
    if match:
        shopid = match.group(1)
        itemid = match.group(2)
        return itemid, shopid
    return None, None

# Đọc file shopee_product_id.csv và lấy tất cả các link
df_id = pd.read_csv('shopee_product_id.csv', header=None) 
product_urls = df_id[0].tolist()  



# Hàm crawl dữ liệu đánh giá cho một sản phẩm
def crawl_comments(item_id, shop_id, max_reviews=10000):
    all_comments = []
    offset = 0
    while len(all_comments) < max_reviews:
        response = make_request(item_id, shop_id, offset)
        if not response:
            break
        json_data = response.json().get('data')
        print(json_data)
        ratings = json_data.get('ratings', [])
        if not ratings:  # Không còn đánh giá
            break
        for rating in ratings:
            comment = rating.get('comment', '').replace('\n', ' ').replace('\r', ' ')
            all_comments.append({
                # 'itemid': rating.get('itemid'),
                # 'shopid': rating.get('shopid'),
                # 'userid': rating.get('userid'),
                'rating_star': rating.get('rating_star'),
                'comment': comment,
                'name': rating.get('product_items')[0].get('name') if rating.get('product_items') else ''
            })
        # Lưu sau mỗi 50 reviews
        if len(all_comments) % 50 == 0:
            df_comment = pd.DataFrame(all_comments)
            df_comment.to_csv('shopee_comments_data.csv', mode='w', header=not os.path.exists('shopee_comments_data.csv'), index=False)
        offset += 50
        time.sleep(1)
    return all_comments

result = []

for url in tqdm(product_urls, desc='Crawling comments'):
    item_id, shop_id = extract_ids_from_url(url)
    if item_id and shop_id:
        print(f'Crawling comments for product {item_id} in shop {shop_id}')
        comments = crawl_comments(item_id, shop_id)
        result.extend(comments)


print("Data saved to shopee_comments_data.csv")
# Out:
# Crawling comments:   0%|          | 0/1 [00:00<?, ?it/s]
# Crawling comments for product 24157440408 in shop 19687597
# 200
# {'ratings': [{'orderid': 0, 'itemid': 24157440408, 'cmtid': 17180277815, 'ctime': 1728975009, 'rating': 1, 'userid': 4282503, 'shopid': 19687597, 'comment': 'Chất liệu:coton mềm mịn\nĐúng với mô tả:Chất liệu mềm mịn, thun mát co dãn tốt\nMàu sắc:trắng\n\nShop này mình đã mua 1 vài sản phẩm và thấy chất lượng khá tốt, vải mặc mềm mát, thấm hút mồ hôi tốt', 'rating_star': 5, 'status': 2, 'mtime': 1733671081, 'editable': 1, 'opt': 2, 'filter': 7, 'is_hidden': False, 'submit_time': 1728975009, 'origin_itemid': 0, 'origin_shopid': 0, 'author_username': 'thanhtam2811', 'author_portrait': '412f6273d3099416b1252354f7f3a8c0', 'author_shopid': 4281219, 'anonymous': False, 'images': ['vn-11134103-7ras8-m1dtz7qja4nwbc'], 'videos': [{'id': 'vn-11110103-6khw8-m1dtzebhndy00e', 'cover': 'https://down-tx-sg.img.susercontent.com/vn-11110103-7ras8-m1dtzgsa1skpe3', 'url': 'https://down-tx-sg.vod.susercontent.com/api/v4/11110103/mms/vn-11110103-6khw8-m1dtzebhndy00e.default.mp4', 'duration': 47133, 'mms_ext': '{"vid":"vn-11110103-6khw8-m1dtzebhndy00e","biz":103,"duration":47133,"create_time":1728974885,"serviceID":6,"cover":"https://down-tx-sg.img.susercontent.com/vn-11110103-7ras8-m1dtzgsa1skpe3","cover_list":null,"formats":[{"format":1600323,"defn":"V540P","profile":"MP4","path":"api/v4/11110103/mms/vn-11110103-6khw8-m1dtzebhndy00e.default.mp4","url":"https://down-tx-sg.vod.susercontent.com/api/v4/11110103/mms/vn-11110103-6khw8-m1dtzebhndy00e.default.mp4","width":640,"height":360,"bitrate":312319,"size":2259922,"fps":25,"duration":47159,"update_time":1728974930}],"default_format":{"format":1600323,"defn":"V540P","profile":"MP4","path":"","url":"https://mms.vod.susercontent.com/api/v4/11110103/mms/vn-11110103-6khw8-m1dtzebhndy00e.default.mp4","width":640,"height":360,"bitrate":312319,"size":2259922,"fps":25,"duration":47159,"update_time":1728974930},"extend_formats":{"H265":[{"format":1600020,"defn":"V360P","profile":"MP4","path":"api/v4/11110103/mms/vn-11110103-6khw8-m1dtzebhndy00e.16000201732610506.mp4","url":"https://down-tx-sg.vod.susercontent.com/api/v4/11110103/mms/vn-11110103-6khw8-m1dtzebhndy00e.16000201732610506.mp4","width":640,"height":360,"bitrate":272222,"size":2215392,"fps":25,"duration":47159,"update_time":1732610532}]},"ab_test":""}', 'cover_image_id': 'sg-11134206-7rdxf-m1h2vulph5dibd', 'highlight': {'id': 'vn-11110103-6khw8-m1dtzebhndy00e', 'cover': 'https://down-tx-sg.img.susercontent.com/vn-11110103-7ras8-m1dtzgsa1skpe3', 'url': 'https://down-tx-sg.vod.susercontent.com/api/v4/11110103/mms/vn-11110103-6khw8-m1dtzebhndy00e.default.mp4', 'duration': 47133, 'mms_ext': '{"vid":"vn-11110103-6khw8-m1dtzebhndy00e","biz":103,"duration":47133,"create_time":1728974885,"serviceID":6,"cover":"https://down-tx-sg.img.susercontent.com/vn-11110103-7ras8-m1dtzgsa1skpe3","cover_list":null,"formats":[{"format":1600323,"defn":"V540P","profile":"MP4","path":"api/v4/11110103/mms/vn-11110103-6khw8-m1dtzebhndy00e.default.mp4","url":"https://down-tx-sg.vod.susercontent.com/api/v4/11110103/mms/vn-11110103-6khw8-m1dtzebhndy00e.default.mp4","width":640,"height":360,"bitrate":312319,"size":2259922,"fps":25,"duration":47159,"update_time":1728974930}],"default_format":{"format":1600323,"defn":"V540P","profile":"MP4","path":"","url":"https://mms.vod.susercontent.com/api/v4/11110103/mms/vn-11110103-6khw8-m1dtzebhndy00e.default.mp4","width":640,"height":360,"bitrate":312319,"size":2259922,"fps":25,"duration":47159,"update_time":1728974930},"extend_formats":{"H265":[{"format":1600020,"defn":"V360P","profile":"MP4","path":"api/v4/11110103/mms/vn-11110103-6khw8-m1dtzebhndy00e.16000201732610506.mp4","url":"https://down-tx-sg.vod.susercontent.com/api/v4/11110103/mms/vn-11110103-6khw8-m1dtzebhndy00e.16000201732610506.mp4","width":640,"height":360,"bitrate":272222,"size":2215392,"fps":25,"duration":47159,"update_time":1732610532}]},"ab_test":""}', 'cover_image_id': 'sg-11134206-7rdxf-m1h2vulph5dibd'}}], 'product_items': [{'itemid': 24157440408, 'shopid': 19687597, 'nam ...
# 200
# {'ratings': [{'orderid': 0, 'itemid': 24157440408, 'cmtid': 14016976159, 'ctime': 1706375233, 'rating': 1, 'userid': 698352439, 'shopid': 19687597, 'comment': 'Đúng với mô tả:đúng mô tả\nChất liệu:mặc k quá nóng vải mát\nMàu sắc:màu kem mn nên mua nhá đẹp lắm á nha', 'rating_star': 5, 'status': 2, 'mtime': 1706376697, 'editable': 1, 'opt': 2, 'filter': 7, 'is_hidden': False, 'submit_time': 1706375233, 'origin_itemid': 0, 'origin_shopid': 0, 'author_username': 'n*****1', 'author_portrait': '', 'author_shopid': 698332854, 'anonymous': True, 'videos': [{'id': 'vn-11110103-6ke17-lr0hwpeijvlwc8', 'cover': 'https://down-bs-sg.img.susercontent.com/vn-11110103-7r98o-lr0hwqtaf4ag6c', 'url': 'https://down-cvs-sg.vod.susercontent.com/api/v4/11110103/mms/vn-11110103-6ke17-lr0hwpeijvlwc8.16000051706375231.mp4', 'duration': 6000, 'mms_ext': '{"vid":"vn-11110103-6ke17-lr0hwpeijvlwc8","biz":103,"duration":6000,"create_time":1706375230,"serviceID":6,"cover":"https://down-bs-sg.img.susercontent.com/vn-11110103-7r98o-lr0hwqtaf4ag6c","cover_list":null,"formats":[{"format":1600005,"defn":"V640P","profile":"MP4","path":"api/v4/11110103/mms/vn-11110103-6ke17-lr0hwpeijvlwc8.16000051706375231.mp4","url":"https://down-cvs-sg.vod.susercontent.com/api/v4/11110103/mms/vn-11110103-6ke17-lr0hwpeijvlwc8.16000051706375231.mp4","width":480,"height":854,"bitrate":423758,"size":318359,"fps":25.16779,"duration":5960,"update_time":1706375233}],"default_format":{"format":1600323,"defn":"V540P","profile":"MP4","path":"","url":"https://mms.vod.susercontent.com/api/v4/11110103/mms/vn-11110103-6ke17-lr0hwpeijvlwc8.default.mp4","width":480,"height":854,"bitrate":357679,"size":269130,"fps":25.16779,"duration":5960,"update_time":1706375244},"extend_formats":{"H265":[{"format":1600018,"defn":"V480P","profile":"MP4","path":"api/v4/11110103/mms/vn-11110103-6ke17-lr0hwpeijvlwc8.16000181726995171.mp4","url":"https://down-cvs-sg.vod.susercontent.com/api/v4/11110103/mms/vn-11110103-6ke17-lr0hwpeijvlwc8.16000181726995171.mp4","width":480,"height":854,"bitrate":602053,"size":453641,"fps":25.16779,"duration":5960,"update_time":1726995180}]},"ab_test":""}', 'cover_image_id': 'sg-11134206-7rcd1-lr0hx3cq25do83', 'highlight': {'id': 'vn-11110103-6ke17-lr0hwpeijvlwc8', 'cover': 'https://down-bs-sg.img.susercontent.com/vn-11110103-7r98o-lr0hwqtaf4ag6c', 'url': 'https://down-cvs-sg.vod.susercontent.com/api/v4/11110103/mms/vn-11110103-6ke17-lr0hwpeijvlwc8.16000051706375231.mp4', 'duration': 6000, 'mms_ext': '{"vid":"vn-11110103-6ke17-lr0hwpeijvlwc8","biz":103,"duration":6000,"create_time":1706375230,"serviceID":6,"cover":"https://down-bs-sg.img.susercontent.com/vn-11110103-7r98o-lr0hwqtaf4ag6c","cover_list":null,"formats":[{"format":1600005,"defn":"V640P","profile":"MP4","path":"api/v4/11110103/mms/vn-11110103-6ke17-lr0hwpeijvlwc8.16000051706375231.mp4","url":"https://down-cvs-sg.vod.susercontent.com/api/v4/11110103/mms/vn-11110103-6ke17-lr0hwpeijvlwc8.16000051706375231.mp4","width":480,"height":854,"bitrate":423758,"size":318359,"fps":25.16779,"duration":5960,"update_time":1706375233}],"default_format":{"format":1600323,"defn":"V540P","profile":"MP4","path":"","url":"https://mms.vod.susercontent.com/api/v4/11110103/mms/vn-11110103-6ke17-lr0hwpeijvlwc8.default.mp4","width":480,"height":854,"bitrate":357679,"size":269130,"fps":25.16779,"duration":5960,"update_time":1706375244},"extend_formats":{"H265":[{"format":1600018,"defn":"V480P","profile":"MP4","path":"api/v4/11110103/mms/vn-11110103-6ke17-lr0hwpeijvlwc8.16000181726995171.mp4","url":"https://down-cvs-sg.vod.susercontent.com/api/v4/11110103/mms/vn-11110103-6ke17-lr0hwpeijvlwc8.16000181726995171.mp4","width":480,"height":854,"bitrate":602053,"size":453641,"fps":25.16779,"duration":5960,"update_time":1726995180}]},"ab_test":""}', 'cover_image_id': 'sg-11134206-7rcd1-lr0hx3cq25do83'}}], 'product_items': [{'itemid': 24157440408, 'shopid': 19687597, 'name': '[Chỉ còn 73.238 đ sau khi áp voucher] Áo thun nam cổ tròn HAFOS cao cấp, lịch lãm H ...
# 200
# {'ratings': [{'orderid': 0, 'itemid': 24157440408, 'cmtid': 13978946376, 'ctime': 1706076838, 'rating': 1, 'userid': 459630379, 'shopid': 19687597, 'comment': 'Hình ảnh và video chỉ mang tính chất nhận xu, đồ chất lượng nên mua nha mn', 'rating_star': 5, 'status': 2, 'mtime': 1706077913, 'editable': 1, 'opt': 2, 'filter': 7, 'is_hidden': False, 'submit_time': 1706076838, 'origin_itemid': 0, 'origin_shopid': 0, 'author_username': 'lieuthuymaile', 'author_portrait': 'f7df8da43d578bf09860454516476b7f', 'author_shopid': 459610802, 'anonymous': False, 'product_items': [{'itemid': 24157440408, 'shopid': 19687597, 'name': '[Chỉ còn 73.238 đ sau khi áp voucher] Áo thun nam cổ tròn HAFOS cao cấp, lịch lãm HAFOS', 'image': 'vn-11134207-7r98o-lqaf8pmkawuq43', 'is_snapshot': 1, 'snapshotid': 42012754749, 'modelid': 240194480873, 'model_name': 'Đỏ,L', 'options': ['Đỏ', 'L']}], 'ItemRatingReply': {'orderid': 0, 'cmtid': 13978946376, 'ctime': 1706077913, 'userid': 19688933, 'comment': 'HAFOS rất vui vì lieuthuymaile  đã dành 5 sao cho các sản phẩm của HAFOS, từng đánh giá xây dựng và sự ủng hộcủa quý khách là động lực cho HAFOS có thể phát triển như bây giờ. HAFOS cám ơn lieuthuymaile bạn rất nhiều ạ <3.', 'mtime': 1706077913, 'is_hidden': False}, 'editable_date': 1708668838, 'sync_to_social': False, 'detailed_rating': {'product_quality': 5, 'seller_service': 5, 'delivery_service': 5, 'driver_service': 5}, 'exclude_scoring_due_low_logistic': False, 'has_template_tag': False, 'sip_info': {'is_oversea': False, 'origin_region': 'vn'}, 'is_repeated_purchase': False, 'overall_fit': 0, 'is_normal_item': True, 'size_info_abt': 'bucket_b', 'key_media': {'key_media_code': 0, 'key_media_id': ''}, 'is_super_review': False, 'region': 'VN', 'original_item_info': {'itemid': 24157440408, 'shopid': 19687597, 'name': 'Áo thun nam cổ tròn HAFOS Áo phông nam basic tay ngắn chất vải cotton cao cấp thấm hút, áo thun trơn basic', 'image': 'vn-11134207-7ras8-m3a57leo9nvla7'}, 'show_super_review_tag': False, 'super_review_status': 0, 'review_type': 0}, {'orderid': 0, 'itemid': 24157440408, 'cmtid': 13958618240, 'ctime': 1705900634, 'rating': 1, 'userid': 825072687, 'shopid': 19687597, 'comment': 'Sp tốt, nên mua, shop nhiệt tình', 'rating_star': 5, 'status': 2, 'mtime': 1705901506, 'editable': 1, 'opt': 2, 'filter': 3, 'is_hidden': False, 'submit_time': 1705900634, 'origin_itemid': 0, 'origin_shopid': 0, 'author_username': 'linhnguyen220294', 'author_portrait': 'vn-11134233-7r98o-luog98vt8nj9a0', 'author_shopid': 825084380, 'anonymous': False, 'product_items': [{'itemid': 24157440408, 'shopid': 19687597, 'name': '[Chỉ còn 73.238 đ sau khi áp voucher] Áo thun nam cổ tròn HAFOS cao cấp, lịch lãm HAFOS', 'image': 'vn-11134207-7r98o-lqaf8pmkawuq43', 'is_snapshot': 1, 'snapshotid': 39012830399, 'modelid': 240194480851, 'model_name': 'Rêu Nhạt,2XL', 'options': ['Rêu Nhạt', '2XL']}], 'ItemRatingReply': {'orderid': 0, 'cmtid': 13958618240, 'ctime': 1705901506, 'userid': 19688933, 'comment': 'HAFOS rất vui vì linhnguyen220294  đã dành 5 sao cho các sản phẩm của HAFOS, từng đánh giá xây dựng và sự ủng hộcủa quý khách là động lực cho HAFOS có thể phát triển như bây giờ. HAFOS cám ơn linhnguyen220294 bạn rất nhiều ạ <3.', 'mtime': 1705901506, 'is_hidden': False}, 'editable_date': 1708492634, 'sync_to_social': False, 'detailed_rating': {'product_quality': 5, 'seller_service': 5, 'delivery_service': 5}, 'exclude_scoring_due_low_logistic': False, 'has_template_tag': False, 'sip_info': {'is_oversea': False, 'origin_region': 'vn'}, 'is_repeated_purchase': False, 'overall_fit': 3, 'is_normal_item': True, 'size_info_abt': 'bucket_b', 'key_media': {'key_media_code': 0, 'key_media_id': ''}, 'is_super_review': False, 'region': 'VN', 'original_item_info': {'itemid': 24157440408, 'shopid': 19687597, 'name': 'Áo thun nam cổ tròn HAFOS Áo phông nam basic tay ngắn chất vải cotton cao cấp thấm hút, áo thun trơn basic', 'image': 'vn-11134207-7ras8-m3a57leo9nvla7'}, 'show_super_review_tag': Fal ...
# 200
# {'ratings': [{'orderid': 0, 'itemid': 24157440408, 'cmtid': 22490141774, 'ctime': 1734163786, 'rating': 1, 'userid': 128215783, 'shopid': 19687597, 'comment': '', 'rating_star': 5, 'status': 2, 'mtime': 1734174168, 'editable': 1, 'opt': 2, 'filter': 0, 'is_hidden': False, 'submit_time': 1734163786, 'origin_itemid': 0, 'origin_shopid': 0, 'author_username': 'shopcuamuoi', 'author_portrait': 'vn-11134233-7ras8-m1ryazm950an09', 'author_shopid': 128213959, 'anonymous': False, 'product_items': [{'itemid': 24157440408, 'shopid': 19687597, 'name': 'Áo thun nam cổ tròn HAFOS Áo phông nam basic tay ngắn chất vải cotton cao cấp thấm hút, áo thun trơn basic', 'image': 'vn-11134207-7ras8-m3a57leo9nvla7', 'is_snapshot': 1, 'snapshotid': 44336177108, 'modelid': 240194480872, 'model_name': 'ATT Đỏ,M', 'options': ['ATT Đỏ', 'M']}, {'itemid': 24157440408, 'shopid': 19687597, 'name': 'Áo thun nam cổ tròn HAFOS Áo phông nam basic tay ngắn chất vải cotton cao cấp thấm hút, áo thun trơn basic', 'image': 'vn-11134207-7ras8-m3a57leo9nvla7', 'is_snapshot': 1, 'snapshotid': 44336177108, 'modelid': 223572757465, 'model_name': 'ATT xanh cổ vịt,2XL', 'options': ['ATT xanh cổ vịt', '2XL']}], 'ItemRatingReply': {'orderid': 0, 'cmtid': 22490141774, 'ctime': 1734174168, 'userid': 19688933, 'comment': 'HAFOS rất vui vì shopcuamuoi  đã dành 5 sao cho các sản phẩm của HAFOS, từng đánh giá xây dựng và sự ủng hộcủa quý khách là động lực cho HAFOS có thể phát triển như bây giờ. HAFOS cám ơn shopcuamuoi bạn rất nhiều ạ <3.', 'mtime': 1734174168, 'is_hidden': False}, 'editable_date': 1736755786, 'sync_to_social': False, 'detailed_rating': {'product_quality': 5, 'seller_service': 5, 'delivery_service': 5, 'driver_service': 5}, 'exclude_scoring_due_low_logistic': False, 'has_template_tag': False, 'sip_info': {'is_oversea': False, 'origin_region': 'vn'}, 'is_repeated_purchase': False, 'display_variation_filter': True, 'overall_fit': 0, 'is_normal_item': True, 'size_info_abt': 'bucket_b', 'key_media': {'key_media_code': 0, 'key_media_id': ''}, 'is_super_review': False, 'region': 'VN', 'original_item_info': {'itemid': 24157440408, 'shopid': 19687597, 'name': 'Áo thun nam cổ tròn HAFOS Áo phông nam basic tay ngắn chất vải cotton cao cấp thấm hút, áo thun trơn basic', 'image': 'vn-11134207-7ras8-m3a57leo9nvla7'}, 'show_super_review_tag': False, 'super_review_status': 0, 'review_type': 0}, {'orderid': 0, 'itemid': 24157440408, 'cmtid': 23352236946, 'ctime': 1734501363, 'rating': 1, 'userid': 322378104, 'shopid': 19687597, 'comment': '', 'rating_star': 5, 'status': 2, 'mtime': 1734508945, 'editable': 1, 'opt': 2, 'filter': 0, 'is_hidden': False, 'submit_time': 1734501363, 'origin_itemid': 0, 'origin_shopid': 0, 'author_username': 'nmyshop.vn', 'author_portrait': 'vn-11134216-7ras8-m2b6ilg3e4dw8b', 'author_shopid': 322358505, 'anonymous': False, 'product_items': [{'itemid': 24157440408, 'shopid': 19687597, 'name': 'Áo thun nam cổ tròn HAFOS Áo phông nam basic tay ngắn chất vải cotton cao cấp thấm hút, áo thun trơn basic', 'image': 'vn-11134207-7ras8-m3a57leo9nvla7', 'is_snapshot': 1, 'snapshotid': 36339847524, 'modelid': 178439296010, 'model_name': 'ATT Nâu đất,M', 'options': ['ATT Nâu đất', 'M']}], 'ItemRatingReply': {'orderid': 0, 'cmtid': 23352236946, 'ctime': 1734508945, 'userid': 19688933, 'comment': 'HAFOS rất vui vì nmyshop.vn  đã dành 5 sao cho các sản phẩm của HAFOS, từng đánh giá xây dựng và sự ủng hộcủa quý khách là động lực cho HAFOS có thể phát triển như bây giờ. HAFOS cám ơn nmyshop.vn bạn rất nhiều ạ <3.', 'mtime': 1734508945, 'is_hidden': False}, 'editable_date': 1737093363, 'sync_to_social': False, 'detailed_rating': {'product_quality': 5, 'seller_service': 5, 'delivery_service': 5}, 'exclude_scoring_due_low_logistic': False, 'has_template_tag': False, 'sip_info': {'is_oversea': False, 'origin_region': 'vn'}, 'is_repeated_purchase': False, 'display_variation_filter': True, 'overall_fit': 0, 'is_normal_item': True, 'size_info_abt': 'bucket_b', 'key_media': {'k ...
# 200
# {'ratings': [{'orderid': 0, 'itemid': 24157440408, 'cmtid': 16338623565, 'ctime': 1724912711, 'rating': 1, 'userid': 512411957, 'shopid': 19687597, 'comment': '', 'rating_star': 5, 'status': 2, 'mtime': 1724918641, 'editable': 1, 'opt': 2, 'filter': 0, 'is_hidden': False, 'submit_time': 1724912711, 'origin_itemid': 0, 'origin_shopid': 0, 'author_username': '.huyen_tran', 'author_portrait': '', 'author_shopid': 512392378, 'anonymous': False, 'product_items': [{'itemid': 24157440408, 'shopid': 19687597, 'name': 'Áo thun nam cổ tròn HAFOS Áo phông nam basic tay ngắn chất vải cotton cao cấp thấm hút', 'image': 'vn-11134207-7r98o-lqo6xqbz9xrrfe', 'is_snapshot': 1, 'snapshotid': 15766439676, 'modelid': 240194480845, 'model_name': 'ATT Xanh Navy,L', 'options': ['ATT Xanh Navy', 'L']}], 'ItemRatingReply': {'orderid': 0, 'cmtid': 16338623565, 'ctime': 1724918641, 'userid': 19688933, 'comment': 'HAFOS rất vui vì .huyen_tran  đã dành 5 sao cho các sản phẩm của HAFOS, từng đánh giá xây dựng và sự ủng hộcủa quý khách là động lực cho HAFOS có thể phát triển như bây giờ. HAFOS cám ơn .huyen_tran bạn rất nhiều ạ <3.', 'mtime': 1724918641, 'is_hidden': False}, 'editable_date': 1727504711, 'sync_to_social': False, 'detailed_rating': {'product_quality': 5, 'seller_service': 5, 'delivery_service': 5}, 'exclude_scoring_due_low_logistic': False, 'has_template_tag': False, 'sip_info': {'is_oversea': False, 'origin_region': 'vn'}, 'is_repeated_purchase': False, 'display_variation_filter': True, 'overall_fit': 2, 'is_normal_item': True, 'size_info_abt': 'bucket_b', 'key_media': {'key_media_code': 0, 'key_media_id': ''}, 'is_super_review': False, 'region': 'VN', 'original_item_info': {'itemid': 24157440408, 'shopid': 19687597, 'name': 'Áo thun nam cổ tròn HAFOS Áo phông nam basic tay ngắn chất vải cotton cao cấp thấm hút, áo thun trơn basic', 'image': 'vn-11134207-7ras8-m3a57leo9nvla7'}, 'show_super_review_tag': False, 'super_review_status': 0, 'review_type': 0}, {'orderid': 0, 'itemid': 24157440408, 'cmtid': 16148459445, 'ctime': 1723388913, 'rating': 1, 'userid': 34182592, 'shopid': 19687597, 'comment': '', 'rating_star': 5, 'status': 2, 'mtime': 1723395875, 'editable': 1, 'opt': 2, 'filter': 0, 'is_hidden': False, 'submit_time': 1723388913, 'origin_itemid': 0, 'origin_shopid': 0, 'author_username': 'binnou', 'author_portrait': '743d5b0c9046a5045672fa7d0ffec22e', 'author_shopid': 34181208, 'anonymous': False, 'product_items': [{'itemid': 24157440408, 'shopid': 19687597, 'name': 'Áo thun nam cổ tròn HAFOS Áo phông nam basic tay ngắn chất vải cotton cao cấp thấm hút', 'image': 'vn-11134207-7r98o-lqo6xqbz9xrrfe', 'is_snapshot': 1, 'snapshotid': 14734784082, 'modelid': 240194480848, 'model_name': 'ATT Rêu Nhạt,M', 'options': ['ATT Rêu Nhạt', 'M']}], 'ItemRatingReply': {'orderid': 0, 'cmtid': 16148459445, 'ctime': 1723395875, 'userid': 19688933, 'comment': 'HAFOS rất vui vì binnou  đã dành 5 sao cho các sản phẩm của HAFOS, từng đánh giá xây dựng và sự ủng hộcủa quý khách là động lực cho HAFOS có thể phát triển như bây giờ. HAFOS cám ơn binnou bạn rất nhiều ạ <3.', 'mtime': 1723395875, 'is_hidden': False}, 'editable_date': 1725980913, 'sync_to_social': False, 'detailed_rating': {'product_quality': 5, 'seller_service': 5, 'delivery_service': 5, 'driver_service': 5}, 'exclude_scoring_due_low_logistic': False, 'has_template_tag': False, 'sip_info': {'is_oversea': False, 'origin_region': 'vn'}, 'is_repeated_purchase': False, 'display_variation_filter': True, 'overall_fit': 0, 'is_normal_item': True, 'size_info_abt': 'bucket_b', 'key_media': {'key_media_code': 0, 'key_media_id': ''}, 'is_super_review': False, 'region': 'VN', 'original_item_info': {'itemid': 24157440408, 'shopid': 19687597, 'name': 'Áo thun nam cổ tròn HAFOS Áo phông nam basic tay ngắn chất vải cotton cao cấp thấm hút, áo thun trơn basic', 'image': 'vn-11134207-7ras8-m3a57leo9nvla7'}, 'show_super_review_tag': False, 'super_review_status': 0, 'review_type': 0}, {'orderid': 0, 'itemid': 2415744040 ...
# 200
# {'ratings': [{'orderid': 0, 'itemid': 24157440408, 'cmtid': 14092575330, 'ctime': 1706969647, 'rating': 1, 'userid': 123039329, 'shopid': 19687597, 'comment': '', 'rating_star': 5, 'status': 2, 'mtime': 1706970705, 'editable': 1, 'opt': 2, 'filter': 0, 'is_hidden': False, 'submit_time': 1706969647, 'origin_itemid': 0, 'origin_shopid': 0, 'author_username': 'vuong_nguyen_0410', 'author_portrait': 'cd193fe028607b79e34737fc60c757a4', 'author_shopid': 123037505, 'anonymous': False, 'product_items': [{'itemid': 24157440408, 'shopid': 19687597, 'name': 'Áo thun nam cổ tròn HAFOS Áo phông nam basic tay ngắn chất vải cotton cao cấp thấm hút', 'image': 'vn-11134207-7r98o-lqo6xqbz9xrrfe', 'is_snapshot': 1, 'snapshotid': 5266873300, 'modelid': 240194480872, 'model_name': 'Đỏ,M', 'options': ['Đỏ', 'M']}], 'ItemRatingReply': {'orderid': 0, 'cmtid': 14092575330, 'ctime': 1706970705, 'userid': 19688933, 'comment': 'HAFOS rất vui vì vuong_nguyen_0410  đã dành 5 sao cho các sản phẩm của HAFOS, từng đánh giá xây dựng và sự ủng hộcủa quý khách là động lực cho HAFOS có thể phát triển như bây giờ. HAFOS cám ơn vuong_nguyen_0410 bạn rất nhiều ạ <3.', 'mtime': 1706970705, 'is_hidden': False}, 'editable_date': 1709561647, 'sync_to_social': False, 'detailed_rating': {'product_quality': 5, 'seller_service': 5, 'delivery_service': 5, 'driver_service': 5}, 'exclude_scoring_due_low_logistic': False, 'has_template_tag': False, 'sip_info': {'is_oversea': False, 'origin_region': 'vn'}, 'is_repeated_purchase': False, 'overall_fit': 0, 'is_normal_item': True, 'size_info_abt': 'bucket_b', 'key_media': {'key_media_code': 0, 'key_media_id': ''}, 'is_super_review': False, 'region': 'VN', 'original_item_info': {'itemid': 24157440408, 'shopid': 19687597, 'name': 'Áo thun nam cổ tròn HAFOS Áo phông nam basic tay ngắn chất vải cotton cao cấp thấm hút, áo thun trơn basic', 'image': 'vn-11134207-7ras8-m3a57leo9nvla7'}, 'show_super_review_tag': False, 'super_review_status': 0, 'review_type': 0}, {'orderid': 0, 'itemid': 24157440408, 'cmtid': 14532931520, 'ctime': 1710522373, 'rating': 1, 'userid': 375119415, 'shopid': 19687597, 'comment': '', 'rating_star': 5, 'status': 2, 'mtime': 1710523892, 'editable': 1, 'opt': 2, 'filter': 0, 'is_hidden': False, 'submit_time': 1710522373, 'origin_itemid': 0, 'origin_shopid': 0, 'author_username': 'tuongoctu', 'author_portrait': '', 'author_shopid': 375099838, 'anonymous': False, 'product_items': [{'itemid': 24157440408, 'shopid': 19687597, 'name': 'Áo thun nam cổ tròn HAFOS Áo phông nam basic tay ngắn chất vải cotton cao cấp thấm hút', 'image': 'vn-11134207-7r98o-lqo6xqbz9xrrfe', 'is_snapshot': 1, 'snapshotid': 23631722835, 'modelid': 240194480865, 'model_name': 'Nâu,L', 'options': ['Nâu', 'L']}, {'itemid': 24157440408, 'shopid': 19687597, 'name': 'Áo thun nam cổ tròn HAFOS Áo phông nam basic tay ngắn chất vải cotton cao cấp thấm hút', 'image': 'vn-11134207-7r98o-lqo6xqbz9xrrfe', 'is_snapshot': 1, 'snapshotid': 23631722835, 'modelid': 240194480857, 'model_name': 'Xám Khói,L', 'options': ['Xám Khói', 'L']}, {'itemid': 24157440408, 'shopid': 19687597, 'name': 'Áo thun nam cổ tròn HAFOS Áo phông nam basic tay ngắn chất vải cotton cao cấp thấm hút', 'image': 'vn-11134207-7r98o-lqo6xqbz9xrrfe', 'is_snapshot': 1, 'snapshotid': 23631722835, 'modelid': 240194480849, 'model_name': 'Rêu Nhạt,L', 'options': ['Rêu Nhạt', 'L']}], 'ItemRatingReply': {'orderid': 0, 'cmtid': 14532931520, 'ctime': 1710523892, 'userid': 19688933, 'comment': 'HAFOS rất vui vì tuongoctu  đã dành 5 sao cho các sản phẩm của HAFOS, từng đánh giá xây dựng và sự ủng hộcủa quý khách là động lực cho HAFOS có thể phát triển như bây giờ. HAFOS cám ơn tuongoctu bạn rất nhiều ạ <3.', 'mtime': 1710523892, 'is_hidden': False}, 'editable_date': 1713114373, 'sync_to_social': False, 'detailed_rating': {'product_quality': 5, 'seller_service': 5, 'delivery_service': 5, 'driver_service': 5}, 'exclude_scoring_due_low_logistic': False, 'has_template_tag': False, 'sip_info': {'is_oversea':  ...
# 200
# {'ratings': [{'orderid': 0, 'itemid': 24157440408, 'cmtid': 14343646640, 'ctime': 1709179065, 'rating': 1, 'userid': 74339149, 'shopid': 19687597, 'comment': '', 'rating_star': 5, 'status': 2, 'mtime': 1709179307, 'editable': 1, 'opt': 2, 'filter': 0, 'is_hidden': False, 'submit_time': 1709179065, 'origin_itemid': 0, 'origin_shopid': 0, 'author_username': 'phuc2u2u', 'author_portrait': '416ea4be0d1104a8a1e1c44ade93973b', 'author_shopid': 74337679, 'anonymous': False, 'product_items': [{'itemid': 24157440408, 'shopid': 19687597, 'name': 'Áo thun nam cổ tròn HAFOS Áo phông nam basic tay ngắn chất vải cotton cao cấp thấm hút', 'image': 'vn-11134207-7r98o-lqo6xqbz9xrrfe', 'is_snapshot': 1, 'snapshotid': 37039940932, 'modelid': 255194478540, 'model_name': 'Trắng,M', 'options': ['Trắng', 'M']}], 'ItemRatingReply': {'orderid': 0, 'cmtid': 14343646640, 'ctime': 1709179307, 'userid': 19688933, 'comment': 'HAFOS rất vui vì phuc2u2u  đã dành 5 sao cho các sản phẩm của HAFOS, từng đánh giá xây dựng và sự ủng hộcủa quý khách là động lực cho HAFOS có thể phát triển như bây giờ. HAFOS cám ơn phuc2u2u bạn rất nhiều ạ <3.', 'mtime': 1709179307, 'is_hidden': False}, 'editable_date': 1711771065, 'sync_to_social': False, 'detailed_rating': {'product_quality': 5, 'seller_service': 5, 'delivery_service': 5}, 'exclude_scoring_due_low_logistic': False, 'has_template_tag': False, 'sip_info': {'is_oversea': False, 'origin_region': 'vn'}, 'is_repeated_purchase': False, 'overall_fit': 0, 'is_normal_item': True, 'size_info_abt': 'bucket_b', 'key_media': {'key_media_code': 0, 'key_media_id': ''}, 'is_super_review': False, 'region': 'VN', 'original_item_info': {'itemid': 24157440408, 'shopid': 19687597, 'name': 'Áo thun nam cổ tròn HAFOS Áo phông nam basic tay ngắn chất vải cotton cao cấp thấm hút, áo thun trơn basic', 'image': 'vn-11134207-7ras8-m3a57leo9nvla7'}, 'show_super_review_tag': False, 'super_review_status': 0, 'review_type': 0}, {'orderid': 0, 'itemid': 24157440408, 'cmtid': 14028196661, 'ctime': 1706491244, 'rating': 1, 'userid': 465462682, 'shopid': 19687597, 'comment': '', 'rating_star': 5, 'status': 2, 'mtime': 1706491904, 'editable': 1, 'opt': 2, 'filter': 0, 'is_hidden': False, 'submit_time': 1706491244, 'origin_itemid': 0, 'origin_shopid': 0, 'author_username': 'meo151092', 'author_portrait': '7f99df17a1df553c3906c995f4a1b81c', 'author_shopid': 465443105, 'anonymous': False, 'product_items': [{'itemid': 24157440408, 'shopid': 19687597, 'name': '[Chỉ còn 73.238 đ sau khi áp voucher] Áo thun nam cổ tròn HAFOS cao cấp, lịch lãm HAFOS', 'image': 'vn-11134207-7r98o-lqaf8pmkawuq43', 'is_snapshot': 1, 'snapshotid': 52012765346, 'modelid': 240194480869, 'model_name': 'Cafe,L', 'options': ['Cafe', 'L']}], 'ItemRatingReply': {'orderid': 0, 'cmtid': 14028196661, 'ctime': 1706491904, 'userid': 19688933, 'comment': 'HAFOS rất vui vì meo151092  đã dành 5 sao cho các sản phẩm của HAFOS, từng đánh giá xây dựng và sự ủng hộcủa quý khách là động lực cho HAFOS có thể phát triển như bây giờ. HAFOS cám ơn meo151092 bạn rất nhiều ạ <3.', 'mtime': 1706491904, 'is_hidden': False}, 'editable_date': 1709083244, 'sync_to_social': False, 'detailed_rating': {'product_quality': 5, 'seller_service': 5, 'delivery_service': 5, 'driver_service': 5}, 'exclude_scoring_due_low_logistic': False, 'has_template_tag': False, 'sip_info': {'is_oversea': False, 'origin_region': 'vn'}, 'is_repeated_purchase': False, 'overall_fit': 0, 'is_normal_item': True, 'size_info_abt': 'bucket_b', 'key_media': {'key_media_code': 0, 'key_media_id': ''}, 'is_super_review': False, 'region': 'VN', 'original_item_info': {'itemid': 24157440408, 'shopid': 19687597, 'name': 'Áo thun nam cổ tròn HAFOS Áo phông nam basic tay ngắn chất vải cotton cao cấp thấm hút, áo thun trơn basic', 'image': 'vn-11134207-7ras8-m3a57leo9nvla7'}, 'show_super_review_tag': False, 'super_review_status': 0, 'review_type': 0}, {'orderid': 0, 'itemid': 24157440408, 'cmtid': 13960456039, 'ctime': 1705911323, 'rating': 1, 'userid' ...
# Crawling comments: 100%|██████████| 1/1 [00:15<00:00, 15.68s/it]
# 200
# {'item_rating_summary': {'rating_total': 320, 'rating_count': [1, 1, 3, 7, 308], 'rcount_with_context': 140, 'rcount_with_image': 67, 'rcount_with_media': 75, 'rcount_local_review': 320, 'rcount_repeat_purchase': 0, 'rcount_overall_fit_small': 1, 'rcount_overall_fit_fit': 80, 'rcount_overall_fit_large': 8, 'rcount_oversea_review': 0, 'rcount_folded': 0, 'show_size_fitting': True, 'fit_small_percentage': 1, 'fit_fit_percentage': 91, 'fit_large_percentage': 8}, 'is_sip_item': True, 'rcmd_algo': 'BUNDLE:comment_search,RECALLER:comment_search_default,QUEUE:comment_search_default,NEWABTEST:0,QUEUES:comment_search_default', 'downgrade_switch': False, 'has_more': False, 'show_local_review': False, 'browsing_ui': '', 'enable_buyer_gallery_media': True, 'size_info_abt': '', 'resize_image_abt': True, 'purchase_bar_abt': 'bucket_a', 'signature': '', 'original_review_summary': {}, 'fe_review_summary': {}, 'similar_section_scenario': 0, 'variation_filters_data': {}}
# Data saved to shopee_comments_data.csv
